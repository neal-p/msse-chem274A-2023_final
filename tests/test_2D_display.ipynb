# %%
from pathlib import Path
import sys

sys.path.insert(0, str(Path('..')))
from MYKit import Mol, SDFToMol

# %%
sdfs = list(Path("../sdf").glob("*.sdf"))
for sdf in sdfs:
    display(SDFToMol(sdf))
